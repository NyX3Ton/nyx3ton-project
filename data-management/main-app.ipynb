# %%
import eurostat
import pandas as pd

# List all datasets to find what you need
# eurostat.get_toc()  # Optional, prints all available datasets

# Fetch the dataset
df = eurostat.get_data_df('tec00115')

# Filter to EU countries and most recent year
filtered = df[(df['geo\\TIME_PERIOD'].isin(['SK', 'DE', 'FR', 'IT', 'PL']))]

# Convert to numeric for analysis
#filtered['values'] = pd.to_numeric(filtered['values'], errors='coerce')
display(filtered.tail(25))
# Out:
#    freq             unit na_item geo\TIME_PERIOD  2013  2014  2015  2016  \
# 8     A      CLV_PCH_PRE    B1GQ              DE   0.4   2.2   1.7   2.2
# 17    A      CLV_PCH_PRE    B1GQ              FR   0.8   1.0   1.1   0.9
# 22    A      CLV_PCH_PRE    B1GQ              IT  -1.8   0.0   0.9   1.2
# 31    A      CLV_PCH_PRE    B1GQ              PL   0.7   3.9   4.4   3.0
# 37    A      CLV_PCH_PRE    B1GQ              SK   0.7   2.7   5.2   1.9
# 49    A  CLV_PCH_PRE_HAB    B1GQ              DE   0.2   1.9   0.9   1.6
# 58    A  CLV_PCH_PRE_HAB    B1GQ              FR   0.3   0.5   0.6   0.5
# 63    A  CLV_PCH_PRE_HAB    B1GQ              IT  -2.0   0.0   1.0   1.4
# 72    A  CLV_PCH_PRE_HAB    B1GQ              PL   0.8   4.0   4.5   3.1
# 78    A  CLV_PCH_PRE_HAB    B1GQ              SK   0.6   2.6   5.1   1.8
#
#     2017  2018  2019  2020  2021  2022  2023  2024
# 8    2.8   1.1   1.0  -4.1   3.9   1.8  -0.9  -0.5
# 17   2.1   1.6   2.0  -7.4   6.9   2.7   1.4   1.2
# 22   1.6   0.8   0.4  -8.9   8.9   4.8   1.0   0.7
# 31   5.2   6.2   4.6  -2.0   6.9   5.3   0.2   3.0
# 37   2.9   4.1   2.3  -2.6   5.7   0.4   2.2   2.1
# 49   2.6   1.0   0.9  -4.0   4.1   1.2  -1.8  -0.8
# 58   1.7   1.2   1.6  -7.8   6.4   2.3   1.2   0.9
# 63   1.8   1.0   0.7  -8.4   9.5   5.0   1.0   0.7
# 72   5.1   6.3   4.6   0.0   7.5   3.0   0.6   3.3
# 78   2.7   3.9   2.1  -2.7   6.1   0.1   2.2   2.0
